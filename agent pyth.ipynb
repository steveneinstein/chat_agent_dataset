# %%
import pandas as pd

# %%
df=pd.read_csv("D:/DS/my tasks/task agent ineuron/AgentPerformance.csv")

# %%
df
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df['Date']
# Out:
# 0      2022-07-30
# 1      2022-07-30
# 2      2022-07-30
# 3      2022-07-30
# 4      2022-07-30
#           ...
# 2155   2022-07-01
# 2156   2022-07-01
# 2157   2022-07-01
# 2158   2022-07-01
# 2159   2022-07-01
# Name: Date, Length: 2160, dtype: datetime64[ns]

# %%
df['Average Response Time']
# Out:
# 0       0:00:38
# 1       0:01:15
# 2       0:00:30
# 3       0:01:04
# 4       0:01:11
#          ...
# 2155    0:00:00
# 2156    0:00:00
# 2157    0:00:00
# 2158    0:00:00
# 2159    0:00:00
# Name: Average Response Time, Length: 2160, dtype: object

# %%
df["Average Response Time"] = pd.to_timedelta(df['Average Response Time'])

# %%
df["Average Response Time"]
# Out:
# 0      0 days 00:00:38
# 1      0 days 00:01:15
# 2      0 days 00:00:30
# 3      0 days 00:01:04
# 4      0 days 00:01:11
#              ...
# 2155   0 days 00:00:00
# 2156   0 days 00:00:00
# 2157   0 days 00:00:00
# 2158   0 days 00:00:00
# 2159   0 days 00:00:00
# Name: Average Response Time, Length: 2160, dtype: timedelta64[ns]

# %%
df["Average Resolution Time"] = pd.to_timedelta(df['Average Resolution Time'])

# %%
df["Average Resolution Time"] = pd.to_numeric(df['Average Resolution Time']/10**9)

# %%
df["Average Response Time"] = pd.to_numeric(df['Average Response Time']/10**9)

# %%
df["Average Response Time"]
# Out:
# 0       38
# 1       75
# 2       30
# 3       64
# 4       71
#         ..
# 2155     0
# 2156     0
# 2157     0
# 2158     0
# 2159     0
# Name: Average Response Time, Length: 2160, dtype: int64

# %%
df["Average Resolution Time"] # gets in sec
# Out:
# 0        260
# 1       1705
# 2        696
# 3        946
# 4        993
#         ...
# 2155       0
# 2156       0
# 2157       0
# 2158       0
# 2159       0
# Name: Average Resolution Time, Length: 2160, dtype: int64

# %%
df
# Out:
#       SL No       Date          Agent Name  Total Chats  \
# 0         1 2022-07-30        Prerna Singh           11
# 1         2 2022-07-30       Nandani Gupta           11
# 2         3 2022-07-30          Ameya Jain           14
# 3         4 2022-07-30       Mahesh Sarade           14
# 4         5 2022-07-30              Swati            14
# ...     ...        ...                 ...          ...
# 2155   2156 2022-07-01   Sowmiya Sivakumar            0
# 2156   2157 2022-07-01             Nitin M            0
# 2157   2158 2022-07-01              Vivek             0
# 2158   2159 2022-07-01       Ayushi Mishra            0
# 2159   2160 2022-07-01  Chaitra K Hiremath            0
#
#       Average Response Time  Average Resolution Time  Average Rating  \
# 0                        38                      260            4.11
# 1                        75                     1705            3.14
# 2                        30                      696            4.55
# ...

# %%
k = '01:20:20'
k.split(':')
n = list(map(int ,(k.split(':'))))
n
# functions has been defined
# Out:
# [1, 20, 20]

# %%
def convert_to_sec(var):
    H,M,S = list(map(int,(var.split(':'))))
    return (H * 60 * 60) + (M *60) + S
convert_to_sec('10:50:50')
# functions has been defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [112], in <cell line: 5>()
#       3     return (H * 60 * 60) + (M *60) + S
#       4 convert_to_sec('10:50:50')
# ----> 5 H
#
# NameError: name 'H' is not defined

# %%
df['Average Response Time'] = df['Average Response Time'].apply(convert_to_sec)

# %%
##############################################TASK############################################################

# %% [markdown]
# # 1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave

# %%
df
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1 2022-07-30        Prerna Singh           11               0:00:38
# 1         2 2022-07-30       Nandani Gupta           11               0:01:15
# 2         3 2022-07-30          Ameya Jain           14               0:00:30
# 3         4 2022-07-30       Mahesh Sarade           14               0:01:04
# 4         5 2022-07-30              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156 2022-07-01   Sowmiya Sivakumar            0               0:00:00
# 2156   2157 2022-07-01             Nitin M            0               0:00:00
# 2157   2158 2022-07-01              Vivek             0               0:00:00
# 2158   2159 2022-07-01       Ayushi Mishra            0               0:00:00
# 2159   2160 2022-07-01  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df.groupby('Agent Name').mean()['Average Rating']
# Out:
# Agent Name
# Abhishek         0.000000
# Aditya           0.000000
# Aditya Shinde    1.800333
# Aditya_iot       2.345333
# Amersh           0.000000
#                    ...
# Uday Mishra      0.000000
# Vasanth P        0.000000
# Vivek            0.500667
# Wasim            2.400000
# Zeeshan          2.287000
# Name: Average Rating, Length: 70, dtype: float64

# %%
df[df[('Average Resolution Time')]>0]['Average Rating'].mean()
# Out:
# 4.235812080536914

# %%
df['week'] = df['Date'].dt.week
# Out:
# C:\Users\einst\AppData\Local\Temp\ipykernel_8964\2978776400.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['week'] = df['Date'].dt.week

# %%
df1=df[df['Average Resolution Time'] != 0]

# %%
df1
# Out:
#       SL No       Date          Agent Name  Total Chats  \
# 0         1 2022-07-30        Prerna Singh           11
# 1         2 2022-07-30       Nandani Gupta           11
# 2         3 2022-07-30          Ameya Jain           14
# 3         4 2022-07-30       Mahesh Sarade           14
# 4         5 2022-07-30              Swati            14
# ...     ...        ...                 ...          ...
# 2101   2102 2022-07-01       Jaydeep Dixit           25
# 2102   2103 2022-07-01  Shivananda Sonwane           23
# 2103   2104 2022-07-01      Khushboo Priya           24
# 2104   2105 2022-07-01     Hrisikesh Neogi           15
# 2105   2106 2022-07-01              Tarun            22
#
#       Average Response Time  Average Resolution Time  Average Rating  \
# 0                        38                      260            4.11
# 1                        75                     1705            3.14
# 2                        30                      696            4.55
# ...

# %%
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1 2022-07-30        Prerna Singh           11       0 days 00:00:38
# 1         2 2022-07-30       Nandani Gupta           11       0 days 00:01:15
# 2         3 2022-07-30          Ameya Jain           14       0 days 00:00:30
# 3         4 2022-07-30       Mahesh Sarade           14       0 days 00:01:04
# 4         5 2022-07-30              Swati            14       0 days 00:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156 2022-07-01   Sowmiya Sivakumar            0       0 days 00:00:00
# 2156   2157 2022-07-01             Nitin M            0       0 days 00:00:00
# 2157   2158 2022-07-01              Vivek             0       0 days 00:00:00
# 2158   2159 2022-07-01       Ayushi Mishra            0       0 days 00:00:00
# 2159   2160 2022-07-01  Chaitra K Hiremath            0       0 days 00:00:00
#
# ...

# %%
df3=df1.groupby(['Agent Name','week']).mean()

# %%
df.groupby

# %%
df3.to_csv('df3_test1.csv')

# %%
df3
# Out:
#                       SL No  Total Chats  Average Resolution Time  \
# Agent Name    week
# Aditya Shinde 26    1985.00         45.5                  1390.50
#               27    1715.60         17.4                  1265.40
#               28    1213.60         19.8                  1902.20
# Aditya_iot    27    1634.00          8.0                  1084.50
#               28    1228.60         14.4                  1275.40
# ...                     ...          ...                      ...
# Wasim         30     235.80         28.8                  1265.80
# Zeeshan       27    1640.50         22.5                  1130.50
#               28    1215.40         38.8                  1378.00
#               29     658.40         31.4                  1112.00
#               30     209.75         36.5                  1160.25
#
#                     Average Rating  Total Feedback
# Agent Name    week
# Aditya Shinde 26             3.850            23.5
# ...

# %% [markdown]
# # 2 .Total working days for each agents

# %%
df.groupby(['Agent Name']).count()['Total Chats']
# Out:
# Agent Name
# Abhishek         30
# Aditya           30
# Aditya Shinde    30
# Aditya_iot       30
# Amersh           30
#                  ..
# Uday Mishra      30
# Vasanth P        30
# Vivek            30
# Wasim            30
# Zeeshan          30
# Name: Total Chats, Length: 70, dtype: int64

# %% [markdown]
# # 3. Total query that you hvae taken

# %%
df1.groupby(['Agent Name']).sum()['Total Chats']
# Out:
# Agent Name
# Aditya Shinde             277
# Aditya_iot                231
# Ameya Jain                322
# Anirudh                    81
# Ankitjha                    5
# Anurag Tiwari               4
# Aravind                   366
# Ashad Nasim                18
# Ayushi Mishra             514
# Bharath                   369
# Boktiar Ahmed Bappy       452
# Chaitra K Hiremath         64
# Deepranjan Gupta          493
# Dibyanshu                   1
# Harikrishnan Shaji        381
# Hitesh Choudhary            1
# Hrisikesh Neogi           578
# Ishawant Kumar            338
# Jawala Prakash            439
# Jayant Kumar              127
# Jaydeep Dixit             512
# Khushboo Priya            446
# Madhulika G               469
# Mahak                       7
# Mahesh Sarade             364
# Maitry                    542
# Maneesh                     4
# Manjunatha A              413
# Mithun S                  503
# Mukesh                     19
# ...

# %% [markdown]
# # 4. total Feedback that you have received

# %%
df1.groupby(['Agent Name']).sum()['Total Feedback']
# Out:
# Agent Name
# Aditya Shinde             153
# Aditya_iot                131
# Ameya Jain                228
# Anirudh                    39
# Ankitjha                    3
# Anurag Tiwari               3
# Aravind                   233
# Ashad Nasim                 9
# Ayushi Mishra             329
# Bharath                   247
# Boktiar Ahmed Bappy       311
# Chaitra K Hiremath         37
# Deepranjan Gupta          312
# Dibyanshu                   0
# Harikrishnan Shaji        231
# Hitesh Choudhary            0
# Hrisikesh Neogi           367
# Ishawant Kumar            202
# Jawala Prakash            250
# Jayant Kumar               70
# Jaydeep Dixit             305
# Khushboo Priya            289
# Madhulika G               281
# Mahak                       5
# Mahesh Sarade             216
# Maitry                    347
# Maneesh                     3
# Manjunatha A              254
# Mithun S                  364
# Mukesh                     17
# ...

# %% [markdown]
# # 5. a agent name who have average rating between 3.5 to 4

# %%
df[(df['Average Rating']>3.5) & (df['Average Rating']<4)]
# Out:
#       SL No       Date           Agent Name  Total Chats  \
# 4         5 2022-07-30               Swati            14
# 10       11 2022-07-30         Manjunatha A           11
# 76       77 2022-07-29        Prateek _iot             8
# 78       79 2022-07-29        Nandani Gupta           24
# 80       81 2022-07-29        Jaydeep Dixit           27
# ...     ...        ...                  ...          ...
# 1869   1870 2022-07-05  Boktiar Ahmed Bappy           24
# 1874   1875 2022-07-04        Ayushi Mishra           29
# 1941   1942 2022-07-04       Jawala Prakash            6
# 2021   2022 2022-07-02        Aditya Shinde           57
# 2023   2024 2022-07-02     Deepranjan Gupta           52
#
#      Average Response Time  Average Resolution Time  Average Rating  \
# 4          0 days 00:01:11                      993            3.67
# 10         0 days 00:00:47                     2576            3.60
# 76         0 days 00:00:36                      641            3.75
# ...

# %% [markdown]
# # 6 . Agent namgroup e who have rating lesss then 3.5

# %%
df1[(df1['Average Rating']<3.5)]
# Out:
#       SL No       Date           Agent Name  Total Chats  \
# 1         2 2022-07-30        Nandani Gupta           11
# 71       72 2022-07-30       Jawala Prakash            4
# 92       93 2022-07-29    Sowmiya Sivakumar           23
# 145     146 2022-07-28     Shiva Srivastava            6
# 148     149 2022-07-28          Aditya_iot             3
# 159     160 2022-07-28         Nishtha Jain           37
# 215     216 2022-07-28  Boktiar Ahmed Bappy            2
# 221     222 2022-07-27          Aditya_iot            15
# 231     232 2022-07-27            Ankitjha             3
# 291     292 2022-07-26            Ankitjha             1
# 298     299 2022-07-26   Chaitra K Hiremath           10
# 306     307 2022-07-26             Mithun S           23
# 358     359 2022-07-26       Jawala Prakash            5
# 644     645 2022-07-22       Ishawant Kumar           23
# 651     652 2022-07-21     Deepranjan Gupta            1
# ...

# %% [markdown]
# # 7 . agent name who have rating more then 4.5

# %%
df1[(df1['Average Rating']>4.5)]
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 2         3 2022-07-30          Ameya Jain           14       0 days 00:00:30
# 3         4 2022-07-30       Mahesh Sarade           14       0 days 00:01:04
# 5         6 2022-07-30             Mukesh             9       0 days 00:00:34
# 6         7 2022-07-30     Saikumarreddy N           15       0 days 00:00:31
# 7         8 2022-07-30       Sanjeev Kumar           12       0 days 00:00:55
# ...     ...        ...                 ...          ...                   ...
# 2100   2101 2022-07-01      Shubham Sharma           22       0 days 00:01:48
# 2101   2102 2022-07-01       Jaydeep Dixit           25       0 days 00:01:15
# 2102   2103 2022-07-01  Shivananda Sonwane           23       0 days 00:01:24
# 2103   2104 2022-07-01      Khushboo Priya           24       0 days 00:01:46
# 2104   2105 2022-07-01     Hrisikesh Neogi           15       0 days 00:01:05
#
# ...

# %% [markdown]
# # 8 . how many feedaback agents have received more then 4.5 average

# %%
df1[(df1['Average Rating']>4.5)].groupby(['Agent Name','Total Feedback']).mean()['Average Rating']
# Out:
# Agent Name     Total Feedback
# Aditya Shinde  7                 4.570000
#                9                 4.835000
#                15                4.730000
# Aditya_iot     2                 5.000000
#                5                 4.733333
#                                    ...
# Wasim          19                4.890000
#                24                4.880000
# Zeeshan        13                4.690000
#                15                4.730000
#                20                4.850000
# Name: Average Rating, Length: 242, dtype: float64

# %%
df1
# Out:
#       SL No       Date          Agent Name  Total Chats  \
# 0         1 2022-07-30        Prerna Singh           11
# 1         2 2022-07-30       Nandani Gupta           11
# 2         3 2022-07-30          Ameya Jain           14
# 3         4 2022-07-30       Mahesh Sarade           14
# 4         5 2022-07-30              Swati            14
# ...     ...        ...                 ...          ...
# 2101   2102 2022-07-01       Jaydeep Dixit           25
# 2102   2103 2022-07-01  Shivananda Sonwane           23
# 2103   2104 2022-07-01      Khushboo Priya           24
# 2104   2105 2022-07-01     Hrisikesh Neogi           15
# 2105   2106 2022-07-01              Tarun            22
#
#       Average Response Time  Average Resolution Time  Average Rating  \
# 0                        38                      260            4.11
# 1                        75                     1705            3.14
# 2                        30                      696            4.55
# ...

# %% [markdown]
# # 9 . average weekly response time for each agent

# %%
df1.groupby(['Agent Name','week']).mean()['Average Response Time']
# Out:
# Agent Name     week
# Aditya Shinde  26       83.00
#                27       66.20
#                28       79.00
# Aditya_iot     27       70.50
#                28       72.80
#                         ...
# Wasim          30       60.60
# Zeeshan        27       82.50
#                28      172.80
#                29       88.00
#                30       95.75
# Name: Average Response Time, Length: 182, dtype: float64

# %% [markdown]
# # 10 . average weekely resolution time for each agents

# %%
df1.groupby(['Agent Name','week']).mean()['Average Resolution Time']
# Out:
# Agent Name     week
# Aditya Shinde  26      1390.50
#                27      1265.40
#                28      1902.20
# Aditya_iot     27      1084.50
#                28      1275.40
#                         ...
# Wasim          30      1265.80
# Zeeshan        27      1130.50
#                28      1378.00
#                29      1112.00
#                30      1160.25
# Name: Average Resolution Time, Length: 182, dtype: float64

# %% [markdown]
# # 11 . list of all agents name

# %%
df.drop_duplicates('Agent Name')['Agent Name']
# Out:
# 0            Prerna Singh
# 1           Nandani Gupta
# 2              Ameya Jain
# 3           Mahesh Sarade
# 4                  Swati
#              ...
# 67    Boktiar Ahmed Bappy
# 68     Shivananda Sonwane
# 69         Ishawant Kumar
# 70       Deepranjan Gupta
# 71         Jawala Prakash
# Name: Agent Name, Length: 70, dtype: object

# %% [markdown]
# # 12 . percentage of chat on which they have received a feedback

# %%
df1
# Out:
#       SL No       Date          Agent Name  Total Chats  \
# 0         1 2022-07-30        Prerna Singh           11
# 1         2 2022-07-30       Nandani Gupta           11
# 2         3 2022-07-30          Ameya Jain           14
# 3         4 2022-07-30       Mahesh Sarade           14
# 4         5 2022-07-30              Swati            14
# ...     ...        ...                 ...          ...
# 2101   2102 2022-07-01       Jaydeep Dixit           25
# 2102   2103 2022-07-01  Shivananda Sonwane           23
# 2103   2104 2022-07-01      Khushboo Priya           24
# 2104   2105 2022-07-01     Hrisikesh Neogi           15
# 2105   2106 2022-07-01              Tarun            22
#
#       Average Response Time  Average Resolution Time  Average Rating  \
# 0                        38                      260            4.11
# 1                        75                     1705            3.14
# 2                        30                      696            4.55
# ...

# %%
df1['Percentage feedback on chats']=(df1['Total Feedback']/df1['Total Chats'])*100
# Out:
# C:\Users\einst\AppData\Local\Temp\ipykernel_8964\1630358916.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Percentage feedback on chats']=(df1['Total Feedback']/df1['Total Chats'])*100

# %%
df1
# Out:
#       SL No       Date          Agent Name  Total Chats  \
# 0         1 2022-07-30        Prerna Singh           11
# 1         2 2022-07-30       Nandani Gupta           11
# 2         3 2022-07-30          Ameya Jain           14
# 3         4 2022-07-30       Mahesh Sarade           14
# 4         5 2022-07-30              Swati            14
# ...     ...        ...                 ...          ...
# 2101   2102 2022-07-01       Jaydeep Dixit           25
# 2102   2103 2022-07-01  Shivananda Sonwane           23
# 2103   2104 2022-07-01      Khushboo Priya           24
# 2104   2105 2022-07-01     Hrisikesh Neogi           15
# 2105   2106 2022-07-01              Tarun            22
#
#       Average Response Time  Average Resolution Time  Average Rating  \
# 0                        38                      260            4.11
# 1                        75                     1705            3.14
# 2                        30                      696            4.55
# ...

# %% [markdown]
# # 13 . Total contributation hour for each and every agents weekly basis

# %%
(df1.groupby(['Agent Name']).sum()['Average Response Time']/(24*60*60)  )
# Out:
# Agent Name
# Aditya Shinde             0.010324
# Aditya_iot                0.011794
# Ameya Jain                0.007338
# Anirudh                   0.007558
# Ankitjha                  0.001539
# Anurag Tiwari             0.002928
# Aravind                   0.007419
# Ashad Nasim               0.013414
# Ayushi Mishra             0.020949
# Bharath                   0.009306
# Boktiar Ahmed Bappy       0.022928
# Chaitra K Hiremath        0.005255
# Deepranjan Gupta          0.018472
# Dibyanshu                 0.000440
# Harikrishnan Shaji        0.011794
# Hitesh Choudhary          0.000000
# Hrisikesh Neogi           0.017535
# Ishawant Kumar            0.017407
# Jawala Prakash            0.032720
# Jayant Kumar              0.006400
# Jaydeep Dixit             0.015417
# Khushboo Priya            0.021285
# Madhulika G               0.023067
# Mahak                     0.000000
# Mahesh Sarade             0.016123
# Maitry                    0.022164
# ...

# %% [markdown]
# # 14. total percentage of active hour for a month

# %%
((df1.groupby(['Agent Name']).sum()['Average Response Time']/(24*60*60))/26)*100
# Out:
# Agent Name
# Aditya Shinde             0.039708
# Aditya_iot                0.045361
# Ameya Jain                0.028223
# Anirudh                   0.029069
# Ankitjha                  0.005921
# Anurag Tiwari             0.011262
# Aravind                   0.028535
# Ashad Nasim               0.051594
# Ayushi Mishra             0.080573
# Bharath                   0.035791
# Boktiar Ahmed Bappy       0.088186
# Chaitra K Hiremath        0.020210
# Deepranjan Gupta          0.071047
# Dibyanshu                 0.001692
# Harikrishnan Shaji        0.045361
# Hitesh Choudhary          0.000000
# Hrisikesh Neogi           0.067441
# Ishawant Kumar            0.066952
# Jawala Prakash            0.125846
# Jayant Kumar              0.024617
# Jaydeep Dixit             0.059295
# Khushboo Priya            0.081864
# Madhulika G               0.088720
# Mahak                     0.000000
# Mahesh Sarade             0.062010
# Maitry                    0.085248
# ...
